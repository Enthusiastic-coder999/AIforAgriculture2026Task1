# %%
import zipfile
import os

zip_file_path = 'beyond-visible-spectrum-ai-for-agriculture-2026.zip'
extract_dir = 'destination_folder'

os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(f"Extracted files to: {extract_dir}")
# Out:
# Extracted files to: destination_folder

# %%
import pandas as pd
from pathlib import Path

base_path = Path('/content/destination_folder/Kaggle_Prepared/train/')
files = [f for f in base_path.rglob('*') if f.is_file()]
types=[]
for file in files:
    types.append(file.name.split('_')[0])

df=pd.DataFrame({'files':files,'types':types})
df.sample(10)
# Out:
#                                                                            files  \
# 449     /content/destination_folder/Kaggle_Prepared/train/HS/Health_hyper_60.tif
# 1260      /content/destination_folder/Kaggle_Prepared/train/MS/Other_hyper_5.tif
# 416    /content/destination_folder/Kaggle_Prepared/train/HS/Health_hyper_187.tif
# 1775   /content/destination_folder/Kaggle_Prepared/train/MS/Health_hyper_153.tif
# 1397    /content/destination_folder/Kaggle_Prepared/train/MS/Other_hyper_181.tif
# 1784      /content/destination_folder/Kaggle_Prepared/train/MS/Rust_hyper_47.tif
# 694   /content/destination_folder/Kaggle_Prepared/train/RGB/Health_hyper_143.png
# 1680     /content/destination_folder/Kaggle_Prepared/train/MS/Rust_hyper_163.tif
# 1344     /content/destination_folder/Kaggle_Prepared/train/MS/Health_hyper_9.tif
# 870      /content/destination_folder/Kaggle_Prepared/train/RGB/Other_hyper_7.png
#
#        types
# 449   Health
# 1260   Other
# 416   Health
# 1775  Health
# 1397   Other
# 1784    Rust
# 694   Health
# 1680    Rust
# 1344  Health
# 870    Other

# %%
from fastai.vision.all import *
import rasterio
import skimage.io as skio

# %%
df['source'] = df['files'].apply(lambda x: x.parent.name)

# %%
import os
from rasterio.enums import Resampling
from pathlib import Path

output_folder = Path('/content/HS_64x64_Upsampled/')
os.makedirs(output_folder, exist_ok=True)

hs_paths = [f for f in files if 'HS' in str(f)]

def process_upsampling(paths, destination):
    print(f"Starting upsampling for {len(paths)} HS files...")

    for p in paths:
        with rasterio.open(p) as src:
            data = src.read(
                out_shape=(src.count, 64, 64),
                resampling=Resampling.bilinear
            )

            profile = src.profile
            transform = src.transform * src.transform.scale(
                (src.width / data.shape[-1]),
                (src.height / data.shape[-2])
            )
            profile.update({"height": 64, "width": 64, "transform": transform})

            with rasterio.open(destination / p.name, 'w', **profile) as dst:
                dst.write(data)

    print("Done! All HS files are now 64x64.")

process_upsampling(hs_paths, output_folder)
# Out:
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_43.tif: BLOCKXSIZE can only be used with TILED=YES
# Starting upsampling for 600 HS files...
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_200.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_151.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_136.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_98.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_190.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_95.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_60.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_200.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_188.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_157.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_50.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_53.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_40.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_81.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_55.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_84.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_23.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_162.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_25.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_181.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_142.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_177.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_16.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_83.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_20.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_27.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_144.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_84.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_78.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_66.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_129.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_126.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_102.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_184.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_166.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_135.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_87.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_158.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_132.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_7.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_29.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_142.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_63.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_121.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_88.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_169.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_109.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_182.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_54.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_130.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_165.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_141.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_106.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_165.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_28.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_195.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_176.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_5.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_44.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_68.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_159.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_92.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_163.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_124.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_57.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_129.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_18.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_197.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_171.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_62.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_162.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_103.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_152.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_41.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_122.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_96.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_25.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_45.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_99.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_94.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_26.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_54.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_71.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_128.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_150.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_57.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_13.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_88.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_183.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_177.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_160.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_45.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_44.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_19.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_180.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_40.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_104.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_107.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_101.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_51.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_8.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_35.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_195.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_135.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_55.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_11.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_4.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_176.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_119.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_52.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_90.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_17.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_9.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_32.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_175.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_115.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_56.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_27.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_183.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_75.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_39.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_189.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_77.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_132.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_49.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_91.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_178.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_108.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_174.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_189.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_5.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_191.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_124.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_105.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_89.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_155.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_127.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_4.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_79.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_9.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_187.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_63.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_5.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_37.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_118.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_196.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_160.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_188.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_58.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_97.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_100.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_89.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_66.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_198.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_184.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_37.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_145.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_35.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_197.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_19.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_1.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_89.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_186.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_199.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_134.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_78.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_117.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_190.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_70.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_72.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_15.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_134.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_23.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_44.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_108.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_178.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_140.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_96.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_111.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_28.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_66.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_61.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_85.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_80.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_115.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_113.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_152.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_3.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_24.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_39.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_148.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_76.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_181.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_79.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_110.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_156.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_34.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_114.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_141.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_98.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_109.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_6.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_91.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_14.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_186.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_107.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_10.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_116.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_109.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_149.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_108.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_180.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_190.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_39.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_170.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_30.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_111.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_58.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_105.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_46.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_38.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_159.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_147.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_24.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_185.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_172.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_136.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_113.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_198.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_178.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_153.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_199.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_45.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_191.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_161.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_194.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_123.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_32.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_48.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_36.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_156.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_40.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_41.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_27.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_1.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_55.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_166.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_137.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_53.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_86.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_133.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_130.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_3.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_175.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_56.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_2.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_140.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_99.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_180.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_102.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_148.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_113.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_104.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_148.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_122.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_125.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_22.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_156.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_136.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_2.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_64.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_187.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_51.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_86.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_22.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_139.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_59.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_118.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_87.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_112.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_185.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_61.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_146.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_143.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_150.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_194.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_184.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_47.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_114.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_101.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_67.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_92.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_170.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_103.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_182.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_162.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_157.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_67.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_77.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_158.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_117.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_95.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_29.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_15.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_173.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_91.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_57.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_174.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_165.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_73.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_97.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_141.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_128.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_68.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_10.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_183.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_145.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_43.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_35.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_120.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_26.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_103.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_138.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_82.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_151.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_132.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_159.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_12.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_112.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_34.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_177.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_12.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_75.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_10.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_80.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_48.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_118.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_138.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_33.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_168.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_51.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_174.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_7.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_93.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_95.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_37.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_147.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_1.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_49.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_121.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_106.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_155.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_54.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_65.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_167.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_104.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_16.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_18.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_119.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_189.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_133.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_188.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_97.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_83.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_72.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_195.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_123.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_149.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_171.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_6.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_119.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_85.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_131.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_21.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_3.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_116.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_102.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_71.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_30.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_110.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_125.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_21.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_18.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_31.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_179.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_13.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_164.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_105.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_142.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_64.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_8.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_76.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_199.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_9.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_140.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_26.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_124.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_14.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_100.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_6.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_151.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_50.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_153.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_193.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_100.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_107.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_29.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_146.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_187.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_166.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_78.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_92.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_90.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_69.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_74.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_46.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_15.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_106.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_60.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_52.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_16.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_75.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_193.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_42.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_23.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_81.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_70.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_42.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_86.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_21.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_149.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_135.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_36.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_62.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_172.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_32.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_161.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_123.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_164.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_197.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_83.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_60.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_154.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_182.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_82.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_11.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_127.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_79.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_171.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_160.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_69.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_73.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_181.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_175.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_38.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_52.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_154.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_191.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_65.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_63.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_50.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_155.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_7.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_139.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_128.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_167.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_22.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_33.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_112.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_59.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_116.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_94.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_163.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_31.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_196.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_173.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_170.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_68.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_154.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_33.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_193.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_77.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_196.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_179.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_12.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_53.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_137.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_20.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_146.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_70.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_11.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_179.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_133.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_163.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_194.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_74.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_82.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_24.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_43.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_127.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_117.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_114.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_13.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_61.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_41.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_167.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_67.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_126.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_20.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_164.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_47.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_147.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_200.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_48.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_46.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_115.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_169.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_42.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_125.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_90.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_126.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_8.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_185.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_121.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_145.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_88.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_158.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_17.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_101.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_143.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_198.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_173.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_134.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_111.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_59.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_71.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_84.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_73.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_99.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_143.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_93.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_56.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_131.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_157.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_137.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_129.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_94.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_30.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_17.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_25.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_14.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_49.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_38.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_96.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_28.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_85.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_62.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_130.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_2.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_81.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_98.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_150.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_36.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_172.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_169.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_122.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_153.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_93.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_161.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_176.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_138.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_69.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_4.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_64.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_192.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_47.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_139.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_31.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_65.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_87.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_76.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_34.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_72.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_186.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_19.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_74.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_152.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_131.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Rust_hyper_80.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Other_hyper_58.tif: BLOCKXSIZE can only be used with TILED=YES
# WARNING:rasterio._env:CPLE_IllegalArg in Health_hyper_110.tif: BLOCKXSIZE can only be used with TILED=YES
# Done! All HS files are now 64x64.

# %%
from pathlib import Path
output_folder = Path('/content/HS_64x64_Clean_Fixed/')
os.makedirs(output_folder, exist_ok=True)

def process_robust_hs(paths, destination):
    clean_indices = list(range(11, 112))

    for p in paths:
        with rasterio.open(p) as src:
            if src.count < 111:
                print(f"Skipping {p.name}: Only has {src.count} bands.")
                continue

            data = src.read(
                clean_indices,
                out_shape=(len(clean_indices), 64, 64),
                resampling=Resampling.bilinear
            )

            profile = src.profile
            profile.update({
                "height": 64,
                "width": 64,
                "count": len(clean_indices),
                "tiled": False
            })
            profile.pop('blockxsize', None)
            profile.pop('blockysize', None)

            with rasterio.open(destination / p.name, 'w', **profile) as dst:
                dst.write(data)

process_robust_hs(hs_paths, output_folder)
# Out:
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:377: NotGeoreferencedWarning: The given matrix is equal to Affine.identity or its flipped counterpart. GDAL may ignore this matrix and save no geotransform without raising an error. This behavior is somewhat driver-specific.
#   dataset = writer(

# %%
test_folder = Path('/content/HS_64x64_Clean_Fixed/')
test_file = next(test_folder.glob('*.tif'))

with rasterio.open(test_file) as src:
    print(f"File: {test_file.name}")
    print(f"Standardized Shape: {src.shape}")
    print(f"Standardized Bands: {src.count}")
# Out:
# File: Rust_hyper_43.tif
# Standardized Shape: (64, 64)
# Standardized Bands: 101

# %%
def update_paths(old_path):
    if 'HS' in str(old_path):
        return Path('/content/HS_64x64_Clean_Fixed') / old_path.name
    return old_path

df['files'] = df['files'].apply(update_paths)

print(df.head())
# Out:
#                                                 files   types source
# 0     /content/HS_64x64_Clean_Fixed/Rust_hyper_43.tif    Rust     HS
# 1  /content/HS_64x64_Clean_Fixed/Health_hyper_200.tif  Health     HS
# 2    /content/HS_64x64_Clean_Fixed/Rust_hyper_151.tif    Rust     HS
# 3   /content/HS_64x64_Clean_Fixed/Other_hyper_136.tif   Other     HS
# 4    /content/HS_64x64_Clean_Fixed/Other_hyper_98.tif   Other     HS

# %%
data_list = []
for p in files:
    actual_path = Path('/content/HS_64x64_Clean_Fixed') / p.name if 'HS' in str(p) else p

    sample_id = re.search(r'(\d+)\.(tif|png)$', p.name).group(1)
    label = p.name.split('_')[0]
    source = 'HS' if 'HS' in str(p) else ('MS' if 'MS' in str(p) else 'RGB')

    data_list.append({'id': sample_id, 'label': label, 'source': source, 'path': actual_path})

multi_df = pd.DataFrame(data_list).pivot(index=['id', 'label'], columns='source', values='path').reset_index()
multi_df.columns.name = None
multi_df = multi_df.rename(columns={'HS': 'hs_path', 'MS': 'ms_path', 'RGB': 'rgb_path'})

# %%
from sklearn.model_selection import train_test_split

train_df, val_df = train_test_split(
    multi_df,
    test_size=0.20,
    stratify=multi_df['label'],
    random_state=42
)

print(f"Split Complete!")
print(f"Training on: {len(train_df)} triplets")
print(f"Validating on: {len(val_df)} triplets")

print("\nClass distribution in Validation set:")
print(val_df['label'].value_counts(normalize=True))
# Out:
# Split Complete!
# Training on: 480 triplets
# Validating on: 120 triplets
#
# Class distribution in Validation set:
# label
# Health    0.333333
# Other     0.333333
# Rust      0.333333
# Name: proportion, dtype: float64

# %%
import torchvision.transforms.functional as TF
import random
class AugmentedDataset(Dataset):
    def __init__(self, dataframe, is_train=True):
        self.df = dataframe
        self.is_train = is_train
        self.label_map = {'Health': 0, 'Other': 1, 'Rust': 2}

    def __len__(self): return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]

        rgb = np.array(Image.open(row['rgb_path']).convert('RGB')).astype(np.float32) / 255.0

        def standardize(path):
            with rasterio.open(path) as src:
                data = src.read().astype(np.float32)
                return (data - data.mean()) / (data.std() + 1e-6)

        ms = standardize(row['ms_path'])
        hs = standardize(row['hs_path'])

        red = ms[2, :, :]
        nir = ms[4, :, :]
        ndvi = (nir - red) / (nir + red + 1e-8)
        ndvi = (ndvi - ndvi.mean()) / (ndvi.std() + 1e-8)
        ndvi = torch.tensor(ndvi).unsqueeze(0)

        rgb = torch.tensor(np.transpose(rgb, (2, 0, 1)))
        ms = torch.tensor(ms)
        hs = torch.tensor(hs)

        ms = torch.cat([ms, ndvi], dim=0)

        if self.is_train:
            if random.random() > 0.5:
                rgb = TF.hflip(rgb); ms = TF.hflip(ms); hs = TF.hflip(hs)
            if random.random() > 0.5:
                rgb = TF.vflip(rgb); ms = TF.vflip(ms); hs = TF.vflip(hs)

        return {
            'rgb': rgb, 'ms': ms, 'hs': hs,
            'label': torch.tensor(self.label_map[row['label']], dtype=torch.long)
        }

# %%
import torch.nn as nn

class SimpleBaselineCNN(nn.Module):
    def __init__(self, num_classes=3):
        super().__init__()
        self.features = nn.Sequential(
            nn.Conv2d(110, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.AdaptiveAvgPool2d((1, 1))
        )

        self.classifier = nn.Sequential(
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, num_classes)
        )

    def forward(self, rgb, ms, hs):
        x = torch.cat((rgb, ms, hs), dim=1)
        x = self.features(x).flatten(1)
        return self.classifier(x)

model = SimpleBaselineCNN(num_classes=3)

# %%
import torch.optim as optim
from torch.utils.data import DataLoader
import torch.nn as nn

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
train_ds = AugmentedDataset(train_df, is_train=True)
val_ds = AugmentedDataset(val_df, is_train=False)
train_loader = DataLoader(train_ds, batch_size=16, shuffle=True)
val_loader = DataLoader(val_ds, batch_size=16, shuffle=False)

model = SimpleBaselineCNN(num_classes=3).to(device)

weights = torch.tensor([1.5, 1.0, 1.2]).to(device)
criterion = nn.CrossEntropyLoss(weight=weights, label_smoothing=0.1)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.05)
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=15)

best_acc = 0.0

print(f"{'Epoch':<8} | {'Train Loss':<12} | {'Val Acc %':<10} | {'Status'}")
print("-" * 55)

for epoch in range(1):
    model.train()
    epoch_loss = 0.0
    for batch in train_loader:
        rgb, ms, hs = batch['rgb'].to(device), batch['ms'].to(device), batch['hs'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(rgb, ms, hs)
        loss = criterion(outputs, labels)

        if torch.isnan(loss):
            continue

        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
        optimizer.step()
        epoch_loss += loss.item()

    scheduler.step()

    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for batch in val_loader:
            rgb, ms, hs = batch['rgb'].to(device), batch['ms'].to(device), batch['hs'].to(device)
            labels = batch['label'].to(device)

            out1 = model(rgb, ms, hs)
            out2 = model(torch.flip(rgb, [3]), torch.flip(ms, [3]), torch.flip(hs, [3]))
            out3 = model(torch.flip(rgb, [2]), torch.flip(ms, [2]), torch.flip(hs, [2]))

            avg_out = (out1 + out2 + out3) / 3
            _, predicted = torch.max(avg_out.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    val_acc = 100 * correct / total

    status = ""
    if val_acc > best_acc:
        best_acc = val_acc
        torch.save(model.state_dict(), 'best_baseline_model.pth')
        status = "SAVED"

    print(f"{epoch+1:<8} | {epoch_loss/len(train_loader):<12.4f} | {val_acc:<10.2f} | {status}")

print(f"\nFinished. Best Accuracy: {best_acc:.2f}%")
# Out:
# Epoch    | Train Loss   | Val Acc %  | Status
# -------------------------------------------------------
# /usr/local/lib/python3.12/dist-packages/rasterio/__init__.py:367: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dataset = DatasetReader(path, driver=driver, sharing=sharing, thread_safe=thread_safe, **kwargs)
# 1        | 0.9524       | 57.50      | SAVED
#
# Finished. Best Accuracy: 57.50%
